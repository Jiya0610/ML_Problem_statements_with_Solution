# %%
# Segment customers into groups
# based on annual income and
# spending score.

# %%
import pandas as pd

# %%
df = pd.read_csv("mall_customer_kmeans_dataset.csv")

# %%
df.head()
# Out:
#   customer_id  age  annual_income  spending_score
# 0        C001   40          56377              33
# 1        C002   56          34043              29
# 2        C003   26         134249              75
# 3        C004   57         140613              23
# 4        C005   33          87615              68

# %%
X = df[['annual_income','spending_score']]

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=4)

# %%
df['cluster'] = model.fit_predict(X)

# %%
print(df.head())
# Out:
#   customer_id  age  annual_income  spending_score  cluster
# 0        C001   40          56377              33        0
# 1        C002   56          34043              29        2
# 2        C003   26         134249              75        1
# 3        C004   57         140613              23        1
# 4        C005   33          87615              68        3

# %%
sample = [[58904,14]]

# %%
model.predict(sample)
# Out:
# C:\Users\jiyam\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([0], dtype=int32)
